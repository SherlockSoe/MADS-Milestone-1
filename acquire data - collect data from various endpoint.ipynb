# %% [markdown]
# # Acquire Data - Collect Education Data from Various Endpoint

# %% [markdown]
# **Table of Contents**
# 1. [Intro](#1.-Intro)
# 2. [Download Data by Different Sources](#2.-Download_Data_by_Different_Sources)
# 3. [Download Data in a Range of Years](#3.-Download_Data_in_a_Range_of_Years)

# %% [markdown]
# ## 1. Intro
#  The US Department of Education releases numerous datasets with educational information every year that can be found at the [Urban Institute’s Education Data Portal](https://educationdata.urban.org/documentation/). We'll write a Python API wrapper to access the following datasets: Common Core Data (CCD) for school-level information such as location, status (open, closed, etc.), type of school (grade school, high school, etc.), among others. In addition, we also pulled data from the Civil Rights Data Collection (CRCD) dataset for race, sex and enrollment data.
#
# The URL follows this format:
# > h<span>ttps</span>://educationdata.urban.org/api/v1/{topic}/{source}/{endpoint}/{year}/[additional_specifiers_or_disaggregators]/[optional filters]
#
# This URL demonstrates an example request for 2013 CDC directory:<br>
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/

# %%
import urllib, json, pandas as pd

# %% [markdown]
# ## 2. Download Data by Different Sources
# According to the data source, we are making functions to deal with different conditions. It generally follows these steps:
# 1. Define url pattern for filtering the exact data we need
# 2. Send the quest and get the response with json file
# 3. Extract data from the json
# 4. Concatenate the data from multiple pages

# %% [markdown]
# Certain variables within the documentation site can be used to subset or filter the data. These variables are found under the “Filter” drop-down menu on the right side of the page. To apply a filter variable to your API call, either select a variable within the drop-down menu or add a query string to the end of the URL. The query string will take the form of:
# > ?filter_variable=filter_value
#
# To include multiple filters, separate them with an &. For instance, if you were interested only in the enrollment of charter schools in the District of Columbia, you could make the following call:<br>
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-3/?charter=1&fips=11

# %%
def school_data(year, dataset, var, grade):
    # Define url pattern for filtering the exact data we need
    base_url = "https://educationdata.urban.org/api/v1/schools/"
    if (dataset, var) == ('ccd', 'directory'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/?school_level=3&school_status=1&school_type=1"
    elif (dataset, var) == ('ccd', 'enrollment'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/grade-"+str(grade)+"/"
    elif (dataset, var) == ('crdc', 'directory'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/"
    elif (dataset, var) == ('crdc', 'enrollment'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/race/sex/?race=99&sex=99"
    elif (dataset, var) == ('crdc', 'school-finance'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/"
    elif (dataset, var) == ('crdc', 'retention'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/grade-"+str(grade)+"/race/sex/?race=99&sex=99"
    elif (dataset, var) == ('crdc', 'sat-act-participation'):
         url = base_url+dataset+"/"+var+"/"+str(year)+"/race/sex/?race=99&sex=99"

    print(url)
    # Send the quest and get the response with json file
    df_lst = []
    while True:
         try:
               response = urllib.request.urlopen(url)
               retention = json.loads(response.read())
               df = pd.json_normalize(retention, record_path= ['results'])
               if response.getcode() == 200:
                   break
         except Exception as inst:
               print (inst)
    df_lst.append(df)
    # Extract data from the json and concatenate the data from multiple pages 
    while retention['next'] != None:
         url = retention['next']
         print(url)
         while True:
               try:
                    response = urllib.request.urlopen(url)
                    retention = json.loads(response.read())
                    df = pd.json_normalize(retention, record_path= ['results'])
                    if response.getcode() == 200:
                         break
               except Exception as inst:
                    print (inst)
         df_lst.append(df)
    # Concatenate the data from multiple pages 
    return pd.concat(df_lst)
    
# Uncommnet to download the files
# ccd_directory_2015 = school_data(2015, 'ccd', 'directory', 12)
# ccd_enrollment_2015 = school_data(2015, 'ccd', 'enrollment', 12)
# crdc_directory_2015 = school_data(2015, 'crdc', 'directory', 12)
# crdc_enrollment_2015 = school_data(2015, 'crdc', 'enrollment', 12)
# crdc_school_finance_2015 = school_data(2015, 'crdc', 'school-finance', 12)
# crdc_retention_2015 = school_data(2015, 'crdc', 'retention', 12)
# crdc_sat_act_participation_2015 = school_data(2015, 'crdc', 'sat-act-participation', 12)
# print(ccd_directory_2015.shape, ccd_enrollment_2015.shape, crdc_directory_2015.shape, crdc_enrollment_2015.shape, crdc_school_finance_2015.shape, crdc_retention_2015.shape, crdc_sat_act_participation_2015.shape)

# %% [markdown]
# ## 3. Download Data in a Range of Years
# We'll make functions for downloading data in a range of years. The idea is to do multiple function calls and restore the data into a list of dataframes.

# %%
def get_ccd_multiple(lst, var, grade):
    df_loop=[]
    for y in lst:
        d = school_data(y, 'ccd', var, grade)
        df_loop.append(d)
    return df_loop
years = [2013, 2015, 2017]

# Uncommnet to download the files
# dfs_ccd_directory = get_ccd_multiple(years, 'directory', 12)
# dfs_g9_enrollment = get_ccd_multiple(years, 'enrollment', 9)
# dfs_g10_enrollment = get_ccd_multiple(years, 'enrollment', 10)
# dfs_g11_enrollment = get_ccd_multiple(years, 'enrollment', 11)
# dfs_g12_enrollment = get_ccd_multiple(years, 'enrollment', 12)
# Out:
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/?school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/?page=2&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/?page=3&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/?page=4&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/?page=5&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2013/?page=6&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2015/?school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2015/?page=2&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2015/?page=3&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2015/?page=4&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2015/?page=5&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2015/?page=6&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2017/?school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2017/?page=2&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2017/?page=3&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2017/?page=4&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2017/?page=5&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/directory/2017/?page=6&school_level=3&school_status=1&school_type=1
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=2
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=3
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=4
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=5
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=6
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=7
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=8
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2013/grade-12/?page=9
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=2
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=3
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=4
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=5
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=6
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=7
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=8
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2015/grade-12/?page=9
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=2
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=3
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=4
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=5
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=6
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=7
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=8
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=9
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=10
# https://educationdata.urban.org/api/v1/schools/ccd/enrollment/2017/grade-12/?page=11

# %%
def get_crdc_multiple(lst, var, grade):
    df_loop=[]
    for y in lst:
        d = school_data(y, 'crdc', var, grade)
        df_loop.append(d)
    return df_loop
years = [2013, 2015, 2017]

# Uncommnet to download the files
# dfs_crdc_sat_act_part = get_crdc_multiple(years, 'sat-act-participation', 12)
# dfs_crdc_school_finance = get_crdc_multiple(years, 'school-finance', 12)
# dfs_crdc_retention = get_crdc_multiple(years, 'retention', 12)
# Out:
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=2&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=3&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=4&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=5&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=6&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=7&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=8&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=9&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=10&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=11&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=12&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=13&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=14&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=15&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=16&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=17&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=18&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=19&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=20&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=21&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=22&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=23&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=24&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=25&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=26&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=27&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=28&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=29&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=30&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=31&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2013/race/sex/?page=32&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=2&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=3&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=4&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=5&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=6&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=7&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=8&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=9&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=10&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=11&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=12&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=13&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=14&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=15&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=16&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=17&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=18&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=19&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=20&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=21&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=22&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=23&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=24&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=25&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=26&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=27&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=28&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=29&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=30&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=31&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=32&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2015/race/sex/?page=33&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=2&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=3&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=4&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=5&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=6&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=7&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=8&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=9&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=10&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=11&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=12&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=13&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=14&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=15&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=16&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=17&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=18&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=19&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=20&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=21&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=22&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=23&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=24&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=25&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=26&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=27&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=28&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=29&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=30&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=31&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=32&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/sat-act-participation/2017/race/sex/?page=33&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=2
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=3
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=4
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=5
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=6
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=7
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=8
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=9
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=10
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=11
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=12
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=13
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=14
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=15
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=16
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=17
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=18
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=19
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=20
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=21
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=22
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=23
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=24
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=25
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=26
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=27
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=28
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=29
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=30
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=31
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2013/?page=32
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=2
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=3
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=4
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=5
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=6
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=7
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=8
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=9
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=10
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=11
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=12
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=13
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=14
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=15
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=16
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=17
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=18
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=19
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=20
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=21
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=22
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=23
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=24
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=25
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=26
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=27
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=28
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=29
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=30
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=31
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=32
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2015/?page=33
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=2
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=3
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=4
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=5
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=6
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=7
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=8
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=9
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=10
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=11
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=12
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=13
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=14
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=15
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=16
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=17
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=18
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=19
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=20
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=21
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=22
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=23
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=24
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=25
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=26
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=27
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=28
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=29
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=30
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=31
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=32
# https://educationdata.urban.org/api/v1/schools/crdc/school-finance/2017/?page=33
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=2&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=3&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=4&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=5&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=6&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=7&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=8&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=9&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=10&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=11&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=12&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=13&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=14&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=15&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=16&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=17&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=18&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=19&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=20&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=21&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=22&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=23&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=24&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=25&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=26&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=27&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=28&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=29&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=30&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=31&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2013/grade-12/race/sex/?page=32&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=2&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=3&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=4&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=5&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=6&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=7&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=8&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=9&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=10&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=11&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=12&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=13&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=14&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=15&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=16&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=17&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=18&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=19&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=20&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=21&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=22&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=23&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=24&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=25&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=26&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=27&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=28&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=29&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=30&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=31&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=32&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2015/grade-12/race/sex/?page=33&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=2&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=3&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=4&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=5&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=6&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=7&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=8&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=9&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=10&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=11&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=12&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=13&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=14&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=15&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=16&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=17&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=18&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=19&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=20&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=21&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=22&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=23&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=24&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=25&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=26&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=27&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=28&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=29&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=30&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=31&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=32&race=99&sex=99
# https://educationdata.urban.org/api/v1/schools/crdc/retention/2017/grade-12/race/sex/?page=33&race=99&sex=99

# %% [markdown]
# ### We'll finally saving the data as cvs files

# %%
i = 2013
for df in dfs_ccd_directory:
    print(df.shape)
    df.to_csv("./educationdata/ccd_directory_" + str(i) + ".csv")
    i+=2
# Out:
# (16310, 52)
# (16532, 52)
# (17922, 52)

# %%
i = 2013
for df in dfs_crdc_sat_act_part:
    print(df.shape)
    df.to_csv("./educationdata/crdc_sat_act_part_" + str(i) + ".csv")
    i+=2
# Out:
# (95507, 10)
# (96360, 10)
# (97632, 10)

# %%
i = 2013
for df in dfs_crdc_school_finance:
    print(df.shape)
    df.to_csv("./educationdata/crdc_school_finance_" + str(i) + ".csv")
    i+=2
# Out:
# (95507, 15)
# (96360, 15)
# (97632, 15)

# %%
i = 2013
for df in dfs_crdc_retention:
    print(df.shape)
    df.to_csv("./educationdata/crdc_retention_" + str(i) + ".csv")
    i+=2
# Out:
# (95507, 11)
# (96360, 11)
# (97632, 11)

# %%
i = 2013
for df in dfs_g9_enrollment:
    print(df.shape)
    df.to_csv("./educationdata/ccd_g9_enrollment_" + str(i) + ".csv")
    i+=2

# %%
i = 2013
for df in dfs_g10_enrollment:
    print(df.shape)
    df.to_csv("./educationdata/ccd_g10_enrollment_" + str(i) + ".csv")
    i+=2

# %%
i = 2013
for df in dfs_g11_enrollment:
    print(df.shape)
    df.to_csv("./educationdata/ccd_g11_enrollment_" + str(i) + ".csv")
    i+=2

# %%
i = 2013
for df in dfs_g12_enrollment:
    print(df.shape)
    df.to_csv("./educationdata/ccd_g12_enrollment_" + str(i) + ".csv")
    i+=2
# Out:
# (26555, 9)
# (26670, 9)
# (32139, 9)
